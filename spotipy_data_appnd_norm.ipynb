# %% [markdown]
# <a href="https://colab.research.google.com/github/lauragabrysiak/mitx_applied_data_science/blob/main/spotipy_data_appnd_norm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mounting the drive
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
import warnings                                 # Used to ignore the warning given as output of the code
warnings.filterwarnings('ignore')
from collections import defaultdict             # A dictionary output that does not raise a key error

import numpy as np                              # Basic libraries of python for numeric and dataframe computations
import pandas as pd

# %%
# Importing the datasets
df_01 = pd.read_csv('/content/sample_data/spotipy_df_temp_final_500.csv'
                  , on_bad_lines='skip')
df_02= pd.read_csv('/content/sample_data/spotipy_df_temp_final_501_1000.csv'
                  , on_bad_lines='skip')

# %%
final_df = df_01.append(df_02, ignore_index=True)

# %%
final_df.shape
# Out:
# (916, 20)

# %% [markdown]
# ## EDA

# %%
# cat var
final_df.describe(include = 'object')#.transpose
# Out:
#           song_title                      song_release song_artist  \
# count            916                               916         916
# unique           365                               288         165
# top     Use Somebody  Ray Guns Are Not Just The Future    Coldplay
# freq              14                                24          54
#
#                                title                   album release_date  \
# count                            916                     916          916
# unique                           360                     308          267
# top     Somebody That I Used To Know  Lungs (Deluxe Edition)   2009-01-01
# freq                              14                      14           40
#
#        album_type                            album_available_markets  \
# count         916                                                916
# unique          3                                                 60
# top         album  ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA...
# freq          770                                                561
#
#           artist artist_genres
# count        916           916
# unique       256           220
# top     Coldplay            []
# freq          34            68

# %%
# num var
final_df.describe(exclude = 'object')#.transpose
# Out:
#              user_id      song_id  play_count    song_year  popularity  \
# count     916.000000   916.000000  916.000000   916.000000  916.000000
# unique           NaN          NaN         NaN          NaN         NaN
# top              NaN          NaN         NaN          NaN         NaN
# freq             NaN          NaN         NaN          NaN         NaN
# mean    46666.897380  4892.412664    1.733624  1772.751092   56.962882
# std     18122.687247  2955.760471    1.046986   641.669471   26.530006
# min      5480.000000    21.000000    1.000000     0.000000    0.000000
# 25%     39814.000000  2115.000000    1.000000  2001.000000   41.000000
# 50%     49549.000000  4911.000000    1.000000  2006.000000   66.000000
# 75%     57932.000000  7628.000000    2.000000  2008.000000   78.000000
# max     75901.000000  9981.000000    5.000000  2010.000000   98.000000
#
#        is_local explicit    duration_ms  artist_popularity  artist_followers
# count       916      916     916.000000         916.000000      9.160000e+02
# unique        1        2            NaN                NaN               NaN
# top       False    False            NaN                NaN               NaN
# freq        916      820            NaN                NaN               NaN
# mean        NaN      NaN  237610.336245          64.712882      1.145642e+07
# std         NaN      NaN   76711.903287          20.376926      2.058979e+07
# min         NaN      NaN   45000.000000           0.000000      1.000000e+00
# 25%         NaN      NaN  197200.000000          56.000000      6.512150e+05
# 50%         NaN      NaN  229973.000000          70.000000      3.294081e+06
# 75%         NaN      NaN  264302.000000          79.000000      9.804638e+06
# max         NaN      NaN  761426.000000         100.000000      1.159353e+08

# %% [markdown]
# #### Analyzing Arrazy Info & Decoding

# %%
market_popularity = (final_df.album_available_markets.str.split(',')
                      .explode()
                      .value_counts()
                      .sort_values(ascending=False))
market_popularity.head(3)  # top 3 markets
# Out:
#  'MX'    807
#  'CR'    764
#  'US'    763
# Name: album_available_markets, dtype: int64

# %%
genre_popularity = (final_df.artist_genres.str.split(',')
                      .explode()
                      .value_counts()
                      .sort_values(ascending=False))
genre_popularity.head(3)    # top 3 genres
# Out:
#  'rock']           130
#  'modern rock'     129
#  'indietronica'    118
# Name: artist_genres, dtype: int64

# %% [markdown]
# ## Pandas Profile

# %%
# Installing Pandas Profile
# !pip install --upgrade matplotlib
# !pip install -U ydata-profiling[notebook]==4.0.0 matplotlib==3.5.1  # last matplotlib is 3.8.1

# %%
from ydata_profiling import ProfileReport       # Adding pandas report

# %%
#### Pandas Report for detailed view original dataset
# Use df_copy
spot_profile = ProfileReport(final_df
                        , title="Spotify Augmd Info Report"
                         #, subtitle="Original Dataset"
                         )

# %%
#spot_profile.to_notebook_iframe()
spot_profile.to_file("spot_profile_001.html")       # for download
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
